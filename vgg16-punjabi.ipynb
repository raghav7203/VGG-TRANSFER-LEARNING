# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import matplotlib.pyplot as plt
import matplotlib.image as img
import tensorflow.keras as keras
import numpy as np

import os
print(os.listdir("../input/punjabiletters/Final_Punjabi/"))
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ['ਰ', 'ਘ', 'ਛ', 'ਢ', 'ਅ', 'ਹ', 'ਝ', 'ਙ', 'ੳ', 'ਜ', 'ਬ', 'ਭ', 'ੲ', 'ੜ', 'ਪ', 'ਥ', 'ਦ', 'ਤ', 'ਖ', 'ਚ', 'ਞ', 'ਯ', 'ਵ', 'ਧ', 'ਨ', 'ਲ', 'ਡ', 'ਮ', 'ਣ']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

batch_size = 32

def generators(shape, preprocessing): 
    '''Create the training and validation datasets for 
    a given image shape.
    '''
    imgdatagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
        preprocessing_function = preprocessing,
        validation_split = 0.1,
    )
    
    
    height, width = shape

    train_dataset = imgdatagen.flow_from_directory(
        '../input/punjabiletters/Final_Punjabi/',
        target_size = (height, width), 
        classes = ('ਰ', 'ਘ', 'ਛ', 'ਢ', 'ਅ', 'ਹ', 'ਝ', 'ਙ', 'ੳ', 'ਜ',
                   'ਬ', 'ਭ', 'ੲ', 'ੜ', 'ਪ', 'ਥ', 'ਦ', 'ਤ', 'ਖ', 'ਚ',
                   'ਞ', 'ਯ', 'ਵ', 'ਧ', 'ਨ', 'ਲ', 'ਡ', 'ਮ', 'ਣ'),
        batch_size = batch_size,
        subset = 'training', 
    )

    val_dataset = imgdatagen.flow_from_directory(
        '../input/punjabiletters/Final_Punjabi/',
        target_size = (height, width), 
        classes = ('ਰ', 'ਘ', 'ਛ', 'ਢ', 'ਅ', 'ਹ', 'ਝ', 'ਙ', 'ੳ', 'ਜ',
                   'ਬ', 'ਭ', 'ੲ', 'ੜ', 'ਪ', 'ਥ', 'ਦ', 'ਤ', 'ਖ', 'ਚ',
                   'ਞ', 'ਯ', 'ਵ', 'ਧ', 'ਨ', 'ਲ', 'ਡ', 'ਮ', 'ਣ'),
        batch_size = batch_size,
        subset = 'validation'
    )
    return train_dataset, val_dataset

# %%
vgg = keras.applications.vgg16

# %%
train_dataset, val_dataset = generators((224,224), preprocessing=vgg.preprocess_input)
# Out:
# Found 10660 images belonging to 29 classes.
# Found 1171 images belonging to 29 classes.

# %%
vgg_conv = vgg.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
# Freeze the layers except the last 4 layers
for layer in vgg_conv.layers[:-4]:
    layer.trainable = False

# Check the trainable status of the individual layers
for layer in vgg_conv.layers:
    print(layer, layer.trainable)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f73bbdecfd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73f759f8d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b90df610> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f73b90aabd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b83fb690> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b90b69d0> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f73b8410150> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b8418d90> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b8410890> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b8422e50> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f73ba399d10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b8430810> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b83bb9d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b83c2890> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f73b83c7c10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b90dfe90> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b83d0f10> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f73b90dfe10> True
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f73b83e4ed0> True

# %%
# Create the model
model = keras.Sequential()

# Add the vgg convolutional base model
model.add(vgg_conv)

# Add new layers
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(1024, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(29, activation='softmax'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                29725
# =================================================================
# Total params: 40,435,549
# Trainable params: 32,800,285
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("../working/model1.h5", monitor = 'val_acc',
                             verbose=1, save_best_only=True,
                             save_weights_only=False, mode='auto', period=1)
# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(lr=1e-4),
              metrics=['acc'])
# Train the model
history = model.fit_generator(
      train_dataset,
      steps_per_epoch=train_dataset.samples/batch_size ,
      epochs=20,
      validation_data=val_dataset,
      validation_steps=val_dataset.samples/batch_size,
      verbose=1,
      callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 334/333 [==============================] - ETA: 0s - loss: 1.3640 - acc: 0.5810
# Epoch 00001: val_acc improved from -inf to 0.77541, saving model to ../working/model1.h5
# 334/333 [==============================] - 185s 553ms/step - loss: 1.3640 - acc: 0.5810 - val_loss: 0.6906 - val_acc: 0.7754
# Epoch 2/20
# 334/333 [==============================] - ETA: 0s - loss: 0.2738 - acc: 0.9144
# Epoch 00002: val_acc improved from 0.77541 to 0.86422, saving model to ../working/model1.h5
# 334/333 [==============================] - 176s 527ms/step - loss: 0.2738 - acc: 0.9144 - val_loss: 0.3989 - val_acc: 0.8642
# Epoch 3/20
# 334/333 [==============================] - ETA: 0s - loss: 0.1700 - acc: 0.9465
# Epoch 00003: val_acc improved from 0.86422 to 0.90436, saving model to ../working/model1.h5
# 334/333 [==============================] - 171s 513ms/step - loss: 0.1700 - acc: 0.9465 - val_loss: 0.2961 - val_acc: 0.9044
# Epoch 4/20
# 334/333 [==============================] - ETA: 0s - loss: 0.1183 - acc: 0.9658
# Epoch 00004: val_acc improved from 0.90436 to 0.95474, saving model to ../working/model1.h5
# 334/333 [==============================] - 172s 514ms/step - loss: 0.1183 - acc: 0.9658 - val_loss: 0.1558 - val_acc: 0.9547
# Epoch 5/20
# 334/333 [==============================] - ETA: 0s - loss: 0.1076 - acc: 0.9677
# Epoch 00005: val_acc did not improve from 0.95474
# 334/333 [==============================] - 170s 510ms/step - loss: 0.1076 - acc: 0.9677 - val_loss: 0.2940 - val_acc: 0.9095
# Epoch 6/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0801 - acc: 0.9765
# Epoch 00006: val_acc did not improve from 0.95474
# 334/333 [==============================] - 171s 513ms/step - loss: 0.0801 - acc: 0.9765 - val_loss: 0.1768 - val_acc: 0.9453
# Epoch 7/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0805 - acc: 0.9762
# Epoch 00007: val_acc did not improve from 0.95474
# 334/333 [==============================] - 171s 513ms/step - loss: 0.0805 - acc: 0.9762 - val_loss: 0.2250 - val_acc: 0.9334
# Epoch 8/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0753 - acc: 0.9770
# Epoch 00008: val_acc did not improve from 0.95474
# 334/333 [==============================] - 169s 507ms/step - loss: 0.0753 - acc: 0.9770 - val_loss: 0.1584 - val_acc: 0.9530
# Epoch 9/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0560 - acc: 0.9826
# Epoch 00009: val_acc improved from 0.95474 to 0.95559, saving model to ../working/model1.h5
# 334/333 [==============================] - 168s 503ms/step - loss: 0.0560 - acc: 0.9826 - val_loss: 0.1749 - val_acc: 0.9556
# Epoch 10/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0570 - acc: 0.9811
# Epoch 00010: val_acc did not improve from 0.95559
# 334/333 [==============================] - 166s 497ms/step - loss: 0.0570 - acc: 0.9811 - val_loss: 0.2056 - val_acc: 0.9445
# Epoch 11/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0564 - acc: 0.9837
# Epoch 00011: val_acc did not improve from 0.95559
# 334/333 [==============================] - 166s 498ms/step - loss: 0.0564 - acc: 0.9837 - val_loss: 0.1908 - val_acc: 0.9419
# Epoch 12/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0497 - acc: 0.9851
# Epoch 00012: val_acc did not improve from 0.95559
# 334/333 [==============================] - 166s 496ms/step - loss: 0.0497 - acc: 0.9851 - val_loss: 0.2372 - val_acc: 0.9385
# Epoch 13/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0551 - acc: 0.9831
# Epoch 00013: val_acc did not improve from 0.95559
# 334/333 [==============================] - 166s 496ms/step - loss: 0.0551 - acc: 0.9831 - val_loss: 0.3126 - val_acc: 0.9137
# Epoch 14/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0533 - acc: 0.9844
# Epoch 00014: val_acc did not improve from 0.95559
# 334/333 [==============================] - 164s 492ms/step - loss: 0.0533 - acc: 0.9844 - val_loss: 0.2125 - val_acc: 0.9479
# Epoch 15/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0448 - acc: 0.9869
# Epoch 00015: val_acc did not improve from 0.95559
# 334/333 [==============================] - 164s 492ms/step - loss: 0.0448 - acc: 0.9869 - val_loss: 0.1857 - val_acc: 0.9436
# Epoch 16/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0353 - acc: 0.9898
# Epoch 00016: val_acc improved from 0.95559 to 0.95645, saving model to ../working/model1.h5
# 334/333 [==============================] - 165s 493ms/step - loss: 0.0353 - acc: 0.9898 - val_loss: 0.1561 - val_acc: 0.9564
# Epoch 17/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0421 - acc: 0.9869
# Epoch 00017: val_acc did not improve from 0.95645
# 334/333 [==============================] - 163s 488ms/step - loss: 0.0421 - acc: 0.9869 - val_loss: 0.2417 - val_acc: 0.9360
# Epoch 18/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0421 - acc: 0.9872
# Epoch 00018: val_acc improved from 0.95645 to 0.95986, saving model to ../working/model1.h5
# 334/333 [==============================] - 163s 488ms/step - loss: 0.0421 - acc: 0.9872 - val_loss: 0.1355 - val_acc: 0.9599
# Epoch 19/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0350 - acc: 0.9893
# Epoch 00019: val_acc did not improve from 0.95986
# 334/333 [==============================] - 162s 486ms/step - loss: 0.0350 - acc: 0.9893 - val_loss: 0.2523 - val_acc: 0.9283
# Epoch 20/20
# 334/333 [==============================] - ETA: 0s - loss: 0.0327 - acc: 0.9896
# Epoch 00020: val_acc improved from 0.95986 to 0.96243, saving model to ../working/model1.h5
# 334/333 [==============================] - 164s 490ms/step - loss: 0.0327 - acc: 0.9896 - val_loss: 0.1420 - val_acc: 0.9624

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(acc)+1)
plt.figure()
plt.plot(epochs, acc, 'b', label = 'Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
# plt.savefig('Accuracy.jpg')
plt.figure()
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
# plt.savefig('Loss.jpg')
